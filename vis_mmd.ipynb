# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

# %%
# ga = pickle.load(open("gano_mmds_4904578.pkl", "rb"))
# resn = pickle.load(open("res_sno_mmds_64360.pkl", "rb"))
# ca = pickle.load(open("car_mmds.pkl", "rb"))
wa = pickle.load(open("test/mmd_test/WaveletFlow_0_epoch_10_mmds_47411920.pkl", "rb"))

# %%
print(wa)
# Out:
# [[array(1587.4197, dtype=float32), array(764.9248, dtype=float32), array(153.40552, dtype=float32)], [16, 32, 64]]

# %%
# res = [2*i for i in range(14, 28)]+[56]
res = [16, 32, 64]
plt.plot(wa[1], wa[0], label="WA")
# plt.plot(res, resn,label="RES")
# plt.plot(res, ca, label="CA")
# plt.xlabel("Resolutions")
# plt.ylabel("MMD")
# # plt.yscale("log")
# plt.legend()
plt.show()

# %%
ng = np.ones(14)
nc = list(range(1,15))
nr = np.ones(14)*50
res = [2*i for i in range(14, 28)]

# %%
plt.plot(res, ng, label="GA")
plt.plot(res, nc,label="CA")
plt.plot(res, nr, label="RES")
plt.xlabel("Resolutions")
plt.ylabel("Number of Function Evaluation")
plt.legend()
plt.show()
